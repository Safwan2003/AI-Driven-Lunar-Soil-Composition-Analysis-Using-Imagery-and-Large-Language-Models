# %% [markdown]
# # Lunar Soil Analysis Experiment
#
# This notebook is for experimenting with the AI pipeline.

# %%
import sys
sys.path.append('../src')

from data.preprocessing import fetch_data
from models.cnn import SimpleCNN
from llm_integration.interpretation import generate_report

# %% [markdown]
# ## 1. Load Data

# %%
lunar_data = fetch_data(source='LRO')

# %% [markdown]
# ## 2. Run Model

# %%
model = SimpleCNN()
# classification = model(lunar_data)
classification = "Highland Regolith" # Placeholder

# %% [markdown]
# ## 3. Generate Report

# %%
minerals = {"Ilmenite": "15%", "Olivine": "10%"}
report = generate_report(classification, minerals)
print(report)
