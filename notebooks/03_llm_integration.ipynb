# %% [markdown]
# # LLM Integration for Lunar Soil Analysis
#
# This notebook demonstrates how to integrate Large Language Models for reasoning and report generation.

# %%
import sys
sys.path.append('..')

from src.llm_integration import LLMAnalyzer
from src.utils import load_config
import os

# %matplotlib inline

# %% [markdown]
# ## Load Configuration and Setup

# %%
config = load_config('../config.yaml')
llm_config = config['llm']

# Ensure API key is set
# os.environ['OPENAI_API_KEY'] = 'your-api-key-here'

# %% [markdown]
# ## Initialize LLM Analyzer

# %%
# analyzer = LLMAnalyzer(llm_config)

# %% [markdown]
# ## Analyze Sample Image

# %%
# Example analysis
# image_path = 'path/to/lunar_image.jpg'
# results = analyzer.analyze_composition(image_path)
# print(results)

# %% [markdown]
# ## Generate Report

# %%
# report = analyzer.generate_report(results)
# print(report)

# %% [markdown]
# ## Save Report

# %%
# with open('../reports/analysis_report.txt', 'w') as f:
#     f.write(report)
