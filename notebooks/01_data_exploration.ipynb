# %% [markdown]
# # Data Exploration for Lunar Soil Analysis
#
# This notebook demonstrates how to explore and visualize lunar imagery datasets.

# %%
import sys
sys.path.append('..')

import numpy as np
import matplotlib.pyplot as plt
from src.data import load_lunar_imagery
from src.utils import load_config

# %matplotlib inline

# %% [markdown]
# ## Load Configuration

# %%
config = load_config('../config.yaml')
print(f"Project: {config['project']['name']}")
print(f"Version: {config['project']['version']}")

# %% [markdown]
# ## Load Sample Data
#
# TODO: Add your lunar imagery to the datasets/ directory and load it here.

# %%
# Example: Load lunar imagery
# images = load_lunar_imagery(config['paths']['data_dir'])
# print(f"Loaded {len(images)} images")

# %% [markdown]
# ## Visualize Samples

# %%
# Example visualization
# fig, axes = plt.subplots(2, 3, figsize=(15, 10))
# for i, ax in enumerate(axes.flat):
#     if i < len(images):
#         ax.imshow(images[i])
#         ax.set_title(f'Sample {i+1}')
#         ax.axis('off')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Data Statistics

# %%
# TODO: Add data statistics
# - Image dimensions
# - Class distribution
# - Pixel value distributions
# - Data quality checks
